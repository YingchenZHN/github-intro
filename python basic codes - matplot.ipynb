# %%
#Jupyter notebooks
#import statement 
#import warning moudle and use warning function warnings.filterwarnings. If more functions need to be played on warnings moudle, check chatgpt
import warnings

warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
my_list=[10,'gold','dollars']

# %%
def f1_score(precision, recall):
    score = 2*precision*recall/(precision + recall)
    score = np.nan_to_num(score)
    
    return(score)

# %%
x = np.linspace(0,1,200)
y = np.linspace(0,1,200)
X,Y = np.meshgrid(x,y)
Z = f1_score(X,Y)
fig = plt.figure()
fig.set_size_inches(20,20)
ax = plt.axes(projection = '3d')
ax.plot_surface(X,Y,Z,rstride =2, cstride = 3, cmap='plasma')

ax.set_title('$F_{1}$ of precision, recall', size=18)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(35, -65)
